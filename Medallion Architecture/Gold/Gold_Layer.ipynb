# %%
from pyspark.sql.functions import *

# %%
df = spark.read.table(table_name)

# %%
gold_df = df.groupBy("col_name").agg(sum("col_name").alias("total"))

# %%
gold_df.write.format("delta")
        .mode("overwrite")
        .option('path', gold_path)
        .saveAsTable(gold_table)
